# %% [markdown]
# # Lab 3: Implement `train_step_gan` from Pseudocode (Goodfellow)

# %%
import torch, torch.nn as nn
criterion=nn.BCEWithLogitsLoss()

def train_step_gan(G,D,opt_g,opt_d,batch_real,z_dim,device=None):
    '''Return (loss_d, loss_g) as floats.'''
    raise NotImplementedError('Implement per pseudocode.')
